# %% [markdown]
# # **Machine Learning With Python: Linear Regression With One Variable**

# %% [markdown]
# ## **Sample problem of predicting home price in monroe, new jersey (USA)**

# %% [markdown]
# * `Problem Statement`: Given above data build a machine learning model that can predict home prices based on square feet area

# %% [markdown]
# * You might remember about linear equation from your high school days math class. Home prices can be presented as following equation:  **home price = m * (area) + b**

# %% [markdown]
# * **Imports**

# %%
import pandas as pd
import numpy as np 
from sklearn import linear_model
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.impute import SimpleImputer
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### **Loading Data**

# %%
df = pd.read_csv('homeprices.csv')

# %% [markdown]
# * Displaying the first 10 rows of the data

# %%
df.head(10)
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %% [markdown]
# ### **Displaying the `Scatter Plot` to show the relationship between the area and the price**

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(x='area', y='price', data=df, marker='+', color='red')

# Adding labels
plt.xlabel('Home Area')
plt.ylabel('Home Price')

plt.show()

# %% [markdown]
# ### **Handling Missing values**

# %% [markdown]
# #### **Drop `Nan` values**

# %%
new_droped_X = df.dropna()
new_droped_y = new_droped_X.price
new_droped_X = new_droped_X.drop('price',axis='columns')

# %% [markdown]
# #### **Impute missing values (replace with mean, median, etc.)**

# %%
imputer = SimpleImputer(strategy='mean')
new_imputed_X = imputer.fit_transform(X)

# %%
new_imputed_X
# Out:
# array([[2.6e+03, 3.0e+00, 2.0e+01],
#        [3.0e+03, 4.0e+00, 1.5e+01],
#        [3.2e+03, 4.2e+00, 1.8e+01],
#        [3.6e+03, 3.0e+00, 3.0e+01],
#        [4.0e+03, 5.0e+00, 8.0e+00],
#        [4.1e+03, 6.0e+00, 8.0e+00]])

# %% [markdown]
# #### **Filling Nans with the meadian of a cloumn**

# %%
bedrooms_median = df['bedrooms'].median()
bedrooms_median
# Out:
# 4.0

# %%
df.bedrooms = df.bedrooms.fillna(df.bedrooms.median())
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %% [markdown]
# ### **Spliting the target `price` from the inputs**

# %%
X = df.drop('price',axis='columns')
X
# Out:
#    area  bedrooms  age
# 0  2600       3.0   20
# 1  3000       4.0   15
# 2  3200       4.0   18
# 3  3600       3.0   30
# 4  4000       5.0    8
# 5  4100       6.0    8

# %%
y = df.price
y
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    595000
# 4    760000
# 5    810000
# Name: price, dtype: int64

# %% [markdown]
# ### **Model Training**

# %% [markdown]
# #### Training a model for `X` which we filled the null values with the median.

# %%
reg = linear_model.LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# * Coeffiecients

# %%
reg.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %% [markdown]
# * Bias

# %%
reg.intercept_
# Out:
# 221323.00186540408

# %% [markdown]
# **Find price of home with `3000 sqr ft` area, `3 bedrooms`, `40 year old`**

# %%
reg.predict([[3000, 3, 40]])
# Out:
# array([498408.25158031])

# %%
112.06244194*3000 + 23388.88007794*3 + -3231.71790863*40 + 221323.00186540408
# Out:
# 498408.2515740241

# %% [markdown]
# **Find price of home with `2500 sqr ft` area, `4 bedrooms`, `5 year old`**

# %%
reg.predict([[2500, 4, 5]])
# Out:
# array([578876.03748933])

# %% [markdown]
# #### Training a model for `new_droped_X` which we droped the missing vlues in.

# %%
reg = linear_model.LinearRegression()
reg.fit(new_droped_X, new_droped_y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([  108.83858908, 26014.7106632 , -2977.4869961 ])

# %% [markdown]
# #### Training a model for `new_imputed_X` which we droped the missing vlues in.

# %%
reg = linear_model.LinearRegression()
reg.fit(new_imputed_X, y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([  116.66950551, 18756.28806982, -3675.75111708])

# %% [markdown]
# ## Now we will do it for area

# %%
X = df.drop(['bedrooms','age','price'],axis='columns')
y = df.price

# %%
X
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000
# 5  4100

# %%
reg = linear_model.LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([167.30954677])

# %%
reg.intercept_
# Out:
# 76692.3818707813

# %%
reg.predict([[3300]])
# Out:
# array([628813.88621022])

# %% [markdown]
# * So now we can conclude the equation which is:
#   `price = 167.30954677 * area + 76692.3818707813`

# %%
167.30954677 * 3300 + 76692.3818707813
# Out:
# 628813.8862117813

# %% [markdown]
# * We can see the same result nearly equals the prediction
